# %% [markdown]
# ## Using the RNC to look at preps in certain windows of verbs

# %%
import random

# %%
from corus import load_morphoru_rnc

path = 'RNCgoldInUD_Morpho.conll'
records = load_morphoru_rnc(path)
rnccorpus = []
for record in records:
    rnccorpus.append(record)

# %%
len(rnccorpus)
# Out:
# 98892

# %%
# example of data
print(random.choice(rnccorpus))
# Out:
# MorphoSent(tokens=[MorphoToken(text='2', lemma='2', pos='NUM', feats={'NumForm': 'Digit'}, feats2={}), MorphoToken(text=')', lemma=')', pos='PUNCT', feats={}, feats2={}), MorphoToken(text='Хоть', lemma='хоть', pos='CONJ', feats={}, feats2={}), MorphoToken(text='и', lemma='и', pos='CONJ', feats={}, feats2={}), MorphoToken(text='на', lemma='на', pos='ADP', feats={}, feats2={}), MorphoToken(text='данном', lemma='данный', pos='ADJ', feats={'Case': 'Loc', 'Gender': 'Masc', 'Number': 'Sing', 'Variant': 'Full'}, feats2={}), MorphoToken(text='этапе', lemma='этап', pos='NOUN', feats={'Animacy': 'Inan', 'Case': 'Loc', 'Gender': 'Masc', 'Number': 'Sing'}, feats2={}), MorphoToken(text='этот', lemma='этот', pos='DET', feats={'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'}, feats2={}), MorphoToken(text='сюжет', lemma='сюжет', pos='NOUN', feats={'Animacy': 'Inan', 'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'}, feats2={}), MorphoToken(text='действительно', lemma='действительно', pos='H', feats={}, feats2={}), MorphoToken(text='может', lemma='мочь', pos='VERB', feats={'Mood': 'Ind', 'Number': 'Sing', 'Person': '3', 'Tense': 'Notpast', 'VerbForm': 'Fin', 'Voice': 'Act'}, feats2={'Subcat': 'Intr', 'Aspect': 'Imp'}), MorphoToken(text='показаться', lemma='показаться', pos='VERB', feats={'VerbForm': 'Inf', 'Voice': 'Mid'}, feats2={'Subcat': 'Intr', 'Aspect': 'Perf'}), MorphoToken(text='скучноватым', lemma='скучноватый', pos='ADJ', feats={'Case': 'Ins', 'Gender': 'Masc', 'Number': 'Sing', 'Variant': 'Full'}, feats2={}), MorphoToken(text=',', lemma=',', pos='PUNCT', feats={}, feats2={}), MorphoToken(text='но', lemma='но', pos='CONJ', feats={}, feats2={}), MorphoToken(text=',', lemma=',', pos='PUNCT', feats={}, feats2={}), MorphoToken(text='как', lemma='как', pos='CONJ', feats={}, feats2={}), MorphoToken(text='по', lemma='по', pos='ADP', feats={}, feats2={}), MorphoToken(text='мне', lemma='я', pos='PRON', feats={'Case': 'Dat', 'Number': 'Sing', 'Person': '1'}, feats2={}), MorphoToken(text=',', lemma=',', pos='PUNCT', feats={}, feats2={}), MorphoToken(text='то', lemma='то', pos='CONJ', feats={}, feats2={}), MorphoToken(text='обыгрывают', lemma='обыгрывать', pos='VERB', feats={'Mood': 'Ind', 'Number': 'Plur', 'Person': '3', 'Tense': 'Notpast', 'VerbForm': 'Fin', 'Voice': 'Act'}, feats2={'Subcat': 'Tran', 'Aspect': 'Imp'}), MorphoToken(text='подобную', lemma='подобный', pos='ADJ', feats={'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing', 'Variant': 'Full'}, feats2={}), MorphoToken(text='ситуацию', lemma='ситуация', pos='NOUN', feats={'Animacy': 'Inan', 'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'}, feats2={}), MorphoToken(text='сейчас', lemma='сейчас', pos='ADV', feats={'Degree': 'Pos'}, feats2={}), MorphoToken(text='везде', lemma='везде', pos='ADV', feats={'Degree': 'Pos'}, feats2={}), MorphoToken(text='по-одинаковому', lemma='по-одинаковому', pos='ADV', feats={'Degree': 'Pos'}, feats2={}), MorphoToken(text='.', lemma='.', pos='PUNCT', feats={}, feats2={})], attrs=[])

# %% [markdown]
# ### script for parsing corpus

# %%
sample = rnccorpus
postags = set()
for sent in sample:
    for token in sent.tokens:
        postags.add(token.pos)
postags
# Out:
# {'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'H',
#  'INTJ',
#  'NOUN',
#  'NUM',
#  'PART',
#  'PRON',
#  'PUNCT',
#  'SYM',
#  'VERB',
#  'X'}

# %%
def build_sentence(tokens, currentindex, adpindex):
    sentence = ''
    for i, token in enumerate(tokens):
        if token.pos == 'PUNCT':
            space = ''
        else:
            space = ' '
        if i in [currentindex, adpindex]:
            text = token.text.upper()
        else:
            text = token.text
        if text == None:
            text = ''
        sentence = sentence + space + text
    return sentence.strip()

sample = rnccorpus
windowList = []
for window in range(1, 5):
    dataDict = dict()
    for sent in sample:
        currentindex = 0
        for token in sent.tokens:
            if token.pos == 'VERB':
                verblemma = token.lemma
                if verblemma not in dataDict:
                    dataDict[verblemma] = dict()
                    dataDict[verblemma]['counts'] = dict()
                    dataDict[verblemma]['sentences'] = dict() 
                for shift in range(-window, window+1):
                    index = currentindex + shift
                    if index >= 0 and index < len(sent.tokens):
                        thistoken = sent.tokens[index]
                        if thistoken.pos == 'ADP':
                            adplemma = thistoken.lemma
                            if adplemma not in dataDict[verblemma]['counts']:                               
                                dataDict[verblemma]['counts'][adplemma] = 0
                                dataDict[verblemma]['sentences'][adplemma] = []
                            dataDict[verblemma]['counts'][adplemma] += 1
                            formattedsent = build_sentence(sent.tokens, currentindex, index)
                            if formattedsent not in dataDict[verblemma]['sentences'][adplemma]:
                                dataDict[verblemma]['sentences'][adplemma].append(formattedsent)
            currentindex += 1
    print(f'window size of {window} complete...')
    windowList.append(dataDict)
# Out:
# window size of 1 complete...
# window size of 2 complete...
# window size of 3 complete...
# window size of 4 complete...

# %%
# removing uncommon verbs (<10 occurrences)
uncommonVerbs = set()
for windowDict in windowList:
    for verb in windowDict:
        totalcount = 0
        countDict = windowDict[verb]['counts']
        for prep in windowDict[verb]['counts']:
            totalcount += windowDict[verb]['counts'][prep]
        if totalcount < 10:
            uncommonVerbs.add(verb)
    for verbtoremove in uncommonVerbs:
        del windowDict[verbtoremove]

# %%
# number of verbs remaining
len(windowList[0])
# Out:
# 433

# %%
okayverbs = list(windowList[0].keys())
print(okayverbs[:10])
# Out:
# ['сказать', 'найти', 'рассказать', 'находить', 'знать', 'плакать', 'смеяться', 'рассказывать', 'ввести', 'вводить']

# %%
pwd
# Out:
# '/Users/paigelee/Desktop/spring2021/clancy/verbinvestigation/data'

# %%
# writing dictionary to json

import json
filepath = '../data.json'

with open(filepath, 'w', encoding='utf8') as json_file:
    json.dump(windowList, json_file, ensure_ascii=False)
    
print(filepath,'written successfully.')
# Out:
# ../data.json written successfully.

# %% [markdown]
# ## breaking down by cases as well

# %%
def build_sentence(tokens, currentindex, adpindex):
    sentence = ''
    for i, token in enumerate(tokens):
        if token.pos == 'PUNCT':
            space = ''
        else:
            space = ' '
        if i in [currentindex, adpindex]:
            text = token.text.upper()
        else:
            text = token.text
        if text == None:
            text = ''
        sentence = sentence + space + text
    return sentence.strip()

# sample = random.sample(rnccorpus,50)
sample = rnccorpus
windowList = []
for window in range(-4, 5):
    dataDict = dict()
    for sent in sample:
        currentindex = 0
        for token in sent.tokens:
            if token.pos == 'VERB':
                verblemma = token.lemma
                if verblemma not in okayverbs:
                    break
                if verblemma not in dataDict:
                    dataDict[verblemma] = dict()
                    dataDict[verblemma]['counts'] = dict()
                    dataDict[verblemma]['sentences'] = dict()
#                 if window < 0:
#                     start = window
#                     end = 0
#                 else:
#                     start = 0
#                     end = window
#                 for shift in range(start, end):
                index = currentindex + window
                if index >= 0 and index < len(sent.tokens):
                    thistoken = sent.tokens[index]
                    if thistoken.pos == 'ADP':
                        adplemma = thistoken.lemma
                        if adplemma not in dataDict[verblemma]['counts']:                               
                            dataDict[verblemma]['counts'][adplemma] = 0
                            dataDict[verblemma]['sentences'][adplemma] = []
                        dataDict[verblemma]['counts'][adplemma] += 1
                        formattedsent = build_sentence(sent.tokens, currentindex, index)
                        if formattedsent not in dataDict[verblemma]['sentences'][adplemma]:
                            dataDict[verblemma]['sentences'][adplemma].append(formattedsent)
            currentindex += 1
    print(f'window size of {window} complete...')
    windowList.append(dataDict)
# Out:
# window size of -4 complete...
# window size of -3 complete...
# window size of -2 complete...
# window size of -1 complete...
# window size of 0 complete...
# window size of 1 complete...
# window size of 2 complete...
# window size of 3 complete...
# window size of 4 complete...

# %%
pwd
# Out:
# '/Users/paigelee/Desktop/spring2021/clancy/verbinvestigation/data'

# %%
# writing dictionary to json

import json
filepath = '../individual_window_data1.json'

with open(filepath, 'w', encoding='utf8') as json_file:
    json.dump(windowList, json_file, ensure_ascii=False)
    
print(filepath,'written successfully.')
# Out:
# ../individual_window_data1.json written successfully.

# %%
# rest is just exploratory parsing...

# %%
allpreps = set()
for windowdict in windowList:
    for verb in windowdict:
        countdict = windowdict[verb]['counts']
        for prep in countdict:
            allpreps.add(prep)

# %%
len(allpreps)
# Out:
# 94

# %%
for prep in sorted(list(allpreps)):
    print(prep)
# Out:
# У
# без
# безо
# благодаря
# близ
# в
# вблизи
# ввиду
# вдогонку
# вдоль
# взамен
# включая
# вместо
# вне
# внизу
# внутри
# внутрь
# во
# возле
# вокруг
# вопреки
# вперед
# впереди
# вроде
# вслед
# вследствие
# высокий
# выше
# для
# до
# за
# из
# из-за
# из-под
# изо
# исключая
# к
# касательно
# ко
# кроме
# меж
# между
# мимо
# на
# над
# надо
# накануне
# наперекор
# наподобие
# напротив
# насчет
# о
# об
# обо
# около
# от
# относительно
# ото
# перед
# передо
# плюс
# по
# поверх
# под
# подле
# подобно
# позади
# помимо
# поперек
# посеред
# посередине
# после
# посреди
# посредине
# посредством
# превыше
# прежде
# при
# про
# против
# путем
# ради
# с
# сверх
# свыше
# сзади
# сквозь
# со
# согласно
# спустя
# среди
# типа
# у
# через

# %%
import json
# make json file
filepath = 'verblabels.json'

with open(filepath, 'w', encoding='utf8') as json_file:
    json.dump(full_json_list, json_file, ensure_ascii=False)
    
print(filepath,'written successfully.')
# Out:
# [{'verb': 'нравиться', 'countdata': {}},
#  {'verb': 'сказать', 'countdata': {'при': 1, 'в': 1}},
#  {'verb': 'подавать', 'countdata': {'при': 1}},
#  {'verb': 'принести', 'countdata': {'из': 1}},
#  {'verb': 'хотеться', 'countdata': {'в': 1, 'об': 2}},
#  {'verb': 'нести', 'countdata': {'у': 1}},
#  {'verb': 'присоединять', 'countdata': {'к': 1}},
#  {'verb': 'идти',
#   'countdata': {'у': 1, 'на': 1, 'о': 2, 'в': 1, 'по': 1, 'без': 1, 'за': 1}},
#  {'verb': 'заниматься', 'countdata': {}},
#  {'verb': 'мочь', 'countdata': {'о': 1, 'на': 2, 'в': 3, 'к': 1, 'по': 1}},
#  {'verb': 'закончить', 'countdata': {}},
#  {'verb': 'расхохотаться', 'countdata': {}},
#  {'verb': 'определить', 'countdata': {}},
#  {'verb': 'иметь', 'countdata': {'к': 1, 'в': 1}},
#  {'verb': 'проводить', 'countdata': {'до': 1}},
#  {'verb': 'поцеловать', 'countdata': {'на': 1}},
#  {'verb': 'быть',
#   'countdata': {'у': 12,
#    'по': 4,
#    'на': 7,
#    'для': 7,
#    'без': 1,
#    'за': 2,
#    'в': 12,
#    'о': 2,
#    'над': 1,
#    'между': 1,
#    'при': 1,
#    'среди': 1,
#    'с': 2,
#    'из': 1}},
#  {'verb': 'гордиться', 'countdata': {}},
#  {'verb': 'говорить',
#   'countdata': {'о': 7, 'по': 2, 'для': 1, 'в': 2, 'у': 1, 'без': 1, 'к': 1}},
#  {'verb': 'видеть', 'countdata': {'за': 1}},
#  {'verb': 'чувствовать', 'countdata': {'в': 1, 'на': 1}},
#  {'verb': 'попасть', 'countdata': {'в': 3, 'о': 1}},
#  {'verb': 'начать', 'countdata': {'на': 1, 'в': 1, 'к': 1, 'без': 1, 'с': 1}},
#  {'verb': 'отрабатывать', 'countdata': {'на': 1}},
#  {'verb': 'казаться', 'countdata': {}},
#  {'verb': 'относиться', 'countdata': {'в': 2, 'к': 4, 'с': 1, 'из': 1}},
#  {'verb': 'описывать', 'countdata': {}},
#  {'verb': 'начинать', 'countdata': {'с': 1}},
#  {'verb': 'течь', 'countdata': {'в': 1}},
#  {'verb': 'обокрасть', 'countdata': {}},
#  {'verb': 'считать', 'countdata': {'из': 1}},
#  {'verb': 'возникать', 'countdata': {'от': 1, 'на': 1}},
#  {'verb': 'связывать', 'countdata': {}},
#  {'verb': 'приехать', 'countdata': {'к': 1}},
#  {'verb': 'оценивать', 'countdata': {}},
#  {'verb': 'разбудить', 'countdata': {}},
#  {'verb': 'заставить', 'countdata': {'на': 1}},
#  {'verb': 'взглянуть', 'countdata': {'на': 3}},
#  {'verb': 'умереть', 'countdata': {'с': 1, 'в': 1}},
#  {'verb': 'бывать', 'countdata': {}},
#  {'verb': 'выплеснуть', 'countdata': {}},
#  {'verb': 'удивляться', 'countdata': {}},
#  {'verb': 'пройти', 'countdata': {'в': 1, 'от': 1, 'по': 1}},
#  {'verb': 'лишиться', 'countdata': {'за': 1}},
#  {'verb': 'отбирать', 'countdata': {}},
#  {'verb': 'посоветовать', 'countdata': {}},
#  {'verb': 'бояться', 'countdata': {}},
#  {'verb': 'хотеть', 'countdata': {'в': 2, 'с': 1, 'из': 1, 'со': 1}},
#  {'verb': 'убить', 'countdata': {}},
#  {'verb': 'сделать', 'countdata': {}},
#  {'verb': 'надеяться', 'countdata': {}},
#  {'verb': 'понравиться', 'countdata': {'в': 1}},
#  {'verb': 'получить', 'countdata': {'в': 1, 'от': 1}},
#  {'verb': 'захватить', 'countdata': {}},
#  {'verb': 'подскочить', 'countdata': {'к': 1}},
#  {'verb': 'спать', 'countdata': {'со': 1}},
#  {'verb': 'прийти', 'countdata': {'в': 3, 'на': 1}},
#  {'verb': 'дернуть', 'countdata': {'за': 1}},
#  {'verb': 'опираться', 'countdata': {'на': 1}},
#  {'verb': 'приходить', 'countdata': {'на': 1, 'к': 1}},
#  {'verb': 'жалеть', 'countdata': {'об': 1}},
#  {'verb': 'забывать', 'countdata': {'о': 1}},
#  {'verb': 'дать', 'countdata': {'в': 1, 'для': 1, 'на': 2}},
#  {'verb': 'уткнуться', 'countdata': {'в': 1}},
#  {'verb': 'стоять', 'countdata': {'перед': 1, 'на': 1}},
#  {'verb': 'слышать', 'countdata': {'об': 1}},
#  {'verb': 'подъехать', 'countdata': {'к': 1}},
#  {'verb': 'приближаться', 'countdata': {'между': 1}},
#  {'verb': 'создаваться', 'countdata': {'для': 1, 'под': 1}},
#  {'verb': 'командировать', 'countdata': {}},
#  {'verb': 'мобилизовать', 'countdata': {}},
#  {'verb': 'привлечь', 'countdata': {'к': 1, 'с': 1}},
#  {'verb': 'сдвинуть', 'countdata': {'с': 1}},
#  {'verb': 'укрепить', 'countdata': {}},
#  {'verb': 'направить', 'countdata': {}},
#  {'verb': 'сплотиться', 'countdata': {}},
#  {'verb': 'называть', 'countdata': {'со': 1}},
#  {'verb': 'объяснять', 'countdata': {}},
#  {'verb': 'освободить', 'countdata': {'от': 1}},
#  {'verb': 'проживать', 'countdata': {}},
#  {'verb': 'сопереживать', 'countdata': {}},
#  {'verb': 'участвовать', 'countdata': {'в': 2}},
#  {'verb': 'дуть', 'countdata': {'из-под': 1}},
#  {'verb': 'обходить', 'countdata': {'на': 1}},
#  {'verb': 'остудить', 'countdata': {}},
#  {'verb': 'уходить', 'countdata': {'на': 1, 'из': 1}},
#  {'verb': 'стать', 'countdata': {'в': 3, 'во': 1, 'по': 1}},
#  {'verb': 'разглагольствовать', 'countdata': {'о': 1}},
#  {'verb': 'получать', 'countdata': {'от': 1, 'в': 1}},
#  {'verb': 'отказаться', 'countdata': {'от': 1}},
#  {'verb': 'ходить', 'countdata': {'в': 1}},
#  {'verb': 'понимать', 'countdata': {'на': 2, 'к': 1, 'между': 1}},
#  {'verb': 'понять', 'countdata': {'из': 1, 'у': 1}},
#  {'verb': 'оставаться', 'countdata': {'для': 1}},
#  {'verb': 'готовить', 'countdata': {'на': 1, 'в': 1}},
#  {'verb': 'жарить', 'countdata': {}},
#  {'verb': 'списывать', 'countdata': {}},
#  {'verb': 'смочь', 'countdata': {'по': 1}},
#  {'verb': 'доставлять', 'countdata': {}},
#  {'verb': 'переносить', 'countdata': {'на': 1}},
#  {'verb': 'здороваться', 'countdata': {}},
#  {'verb': 'прийтись', 'countdata': {}},
#  {'verb': 'мыслить', 'countdata': {}},
#  {'verb': 'загорать', 'countdata': {}},
#  {'verb': 'негде', 'countdata': {}},
#  {'verb': 'привести', 'countdata': {'к': 2, 'в': 2}},
#  {'verb': 'расти', 'countdata': {}},
#  {'verb': 'гудеть', 'countdata': {}},
#  {'verb': 'знать', 'countdata': {'у': 1, 'через': 1}},
#  {'verb': 'жить', 'countdata': {'в': 6, 'на': 1, 'до': 1, 'с': 1}},
#  {'verb': 'писать', 'countdata': {'о': 1, 'про': 1}},
#  {'verb': 'испытать', 'countdata': {}},
#  {'verb': 'становиться', 'countdata': {'по': 1}},
#  {'verb': 'посмотреть', 'countdata': {'на': 1, 'в': 1}},
#  {'verb': 'поддерживать', 'countdata': {'в': 1}},
#  {'verb': 'ошибиться', 'countdata': {}},
#  {'verb': 'схватить', 'countdata': {}},
#  {'verb': 'защитить', 'countdata': {}},
#  {'verb': 'дешифровать', 'countdata': {}},
#  {'verb': 'общаться', 'countdata': {'с': 1}},
#  {'verb': 'встречаться', 'countdata': {'в': 1}},
#  {'verb': 'значить', 'countdata': {}},
#  {'verb': 'учиться', 'countdata': {'в': 1, 'у': 1, 'на': 1}},
#  {'verb': 'смотреть', 'countdata': {'на': 3}},
#  {'verb': 'подрать', 'countdata': {}},
#  {'verb': 'гореть', 'countdata': {}},
#  {'verb': 'упереться', 'countdata': {'в': 1}},
#  {'verb': 'изогнуться', 'countdata': {'на': 1}},
#  {'verb': 'высовываться', 'countdata': {}},
#  {'verb': 'выступать', 'countdata': {'в': 1, 'при': 1}},
#  {'verb': 'предпринимать', 'countdata': {}},
#  {'verb': 'выдержать', 'countdata': {}},
#  {'verb': 'происходить',
#   'countdata': {'на': 1, 'после': 1, 'со': 1, 'во': 1, 'с': 1, 'за': 1}},
#  {'verb': 'оказаться', 'countdata': {}},
#  {'verb': 'рассуждать', 'countdata': {}},
#  {'verb': 'закрыться', 'countdata': {}},
#  {'verb': 'упасть', 'countdata': {'на': 1, 'в': 2}},
#  {'verb': 'проявиться', 'countdata': {'в': 1}},
#  {'verb': 'создать', 'countdata': {'из-за': 1}},
#  {'verb': 'вырабатывать', 'countdata': {}},
#  {'verb': 'уйти', 'countdata': {'в': 1}},
#  {'verb': 'носить', 'countdata': {'от': 1}},
#  {'verb': 'выбросить', 'countdata': {}},
#  {'verb': 'выбрасывать', 'countdata': {}},
#  {'verb': 'делать', 'countdata': {'для': 1, 'с': 1, 'по': 1}},
#  {'verb': 'провести', 'countdata': {'по': 1}},
#  {'verb': 'пользоваться', 'countdata': {}},
#  {'verb': 'воспользоваться', 'countdata': {'из': 1}},
#  {'verb': 'объяснить', 'countdata': {'в': 1, 'из': 1}},
#  {'verb': 'побить', 'countdata': {}},
#  {'verb': 'двигаться', 'countdata': {}},
#  {'verb': 'заряжаться', 'countdata': {}},
#  {'verb': 'служить', 'countdata': {}},
#  {'verb': 'захотеться', 'countdata': {'через': 1}},
#  {'verb': 'почитать', 'countdata': {}},
#  {'verb': 'существовать', 'countdata': {'в': 2, 'у': 1}},
#  {'verb': 'танцевать', 'countdata': {'с': 1}},
#  {'verb': 'осуществляться', 'countdata': {'из': 1}},
#  {'verb': 'создавать', 'countdata': {'для': 1}},
#  {'verb': 'слушать', 'countdata': {'в': 1}},
#  {'verb': 'комментировать', 'countdata': {'на': 1}},
#  {'verb': 'убедить', 'countdata': {}},
#  {'verb': 'поймать', 'countdata': {}},
#  {'verb': 'учить', 'countdata': {'без': 1}},
#  {'verb': 'снимать', 'countdata': {}},
#  {'verb': 'опускаться', 'countdata': {'до': 1, 'на': 1}},
#  {'verb': 'упускать', 'countdata': {}},
#  {'verb': 'обучить', 'countdata': {}},
#  {'verb': 'состояться', 'countdata': {}},
#  {'verb': 'потребовать', 'countdata': {'из': 1}},
#  {'verb': 'отражаться', 'countdata': {'в': 1}},
#  {'verb': 'заболеть', 'countdata': {}},
#  {'verb': 'думать', 'countdata': {'по': 1, 'в': 2, 'об': 1, 'о': 1}},
#  {'verb': 'приносить', 'countdata': {}},
#  {'verb': 'агитировать', 'countdata': {'за': 1}},
#  {'verb': 'являться', 'countdata': {'по': 2}},
#  {'verb': 'потерять', 'countdata': {}},
#  {'verb': 'превратиться', 'countdata': {'в': 1}},
#  {'verb': 'вспомнить', 'countdata': {'о': 2, 'во': 1}},
#  {'verb': 'просить', 'countdata': {'о': 1, 'с': 1}},
#  {'verb': 'предлагать', 'countdata': {'в': 1}},
#  {'verb': 'представить', 'countdata': {}},
#  {'verb': 'исчезнуть', 'countdata': {}},
#  {'verb': 'дождаться', 'countdata': {}},
#  {'verb': 'затевать', 'countdata': {}},
#  {'verb': 'исполнять', 'countdata': {}},
#  {'verb': 'встретиться', 'countdata': {'с': 3}},
#  {'verb': 'повернуться', 'countdata': {'к': 1}},
#  {'verb': 'замечать', 'countdata': {'у': 1}},
#  {'verb': 'учитывать', 'countdata': {}},
#  {'verb': 'составить', 'countdata': {'в': 2}},
#  {'verb': 'составлять', 'countdata': {'по': 1}},
#  {'verb': 'поместить', 'countdata': {'в': 1}},
#  {'verb': 'показать', 'countdata': {}},
#  {'verb': 'показаться', 'countdata': {}},
#  {'verb': 'развиваться', 'countdata': {}},
#  {'verb': 'судиться', 'countdata': {'против': 1}},
#  {'verb': 'выиграть', 'countdata': {'в': 1, 'у': 1}},
#  {'verb': 'молвить', 'countdata': {}},
#  {'verb': 'приходиться', 'countdata': {'на': 1}},
#  {'verb': 'прогуливать', 'countdata': {}},
#  {'verb': 'рисковать', 'countdata': {}},
#  {'verb': 'даваться', 'countdata': {'с': 1}},
#  {'verb': 'сводить', 'countdata': {'к': 1}},
#  {'verb': 'ответить', 'countdata': {}},
#  {'verb': 'упомянуть', 'countdata': {}},
#  {'verb': 'разлетаться', 'countdata': {}},
#  {'verb': 'произнестись', 'countdata': {}},
#  {'verb': 'записаться', 'countdata': {}},
#  {'verb': 'признать', 'countdata': {'в': 1}},
#  {'verb': 'выплачиваться', 'countdata': {}},
#  {'verb': 'означать', 'countdata': {'между': 1}},
#  {'verb': 'взять', 'countdata': {'в': 1, 'с': 1}},
#  {'verb': 'найти', 'countdata': {'в': 2}},
#  {'verb': 'нет', 'countdata': {'в': 2, 'у': 1, 'при': 1, 'на': 1}},
#  {'verb': 'протащить', 'countdata': {'по': 1}},
#  {'verb': 'отворачиваться', 'countdata': {'к': 1}},
#  {'verb': 'ронять', 'countdata': {}},
#  {'verb': 'сидеть', 'countdata': {'в': 3, 'за': 1}},
#  {'verb': 'есть', 'countdata': {}},
#  {'verb': 'пить', 'countdata': {'с': 2}},
#  {'verb': 'подтолкнуть', 'countdata': {'к': 1}},
#  {'verb': 'стоить', 'countdata': {'на': 1}},
#  {'verb': 'воевать', 'countdata': {'с': 1}},
#  {'verb': 'вернуться', 'countdata': {'в': 1, 'у': 1, 'на': 1}},
#  {'verb': 'сохранить', 'countdata': {'за': 1}},
#  {'verb': 'помешать', 'countdata': {}},
#  {'verb': 'гулять', 'countdata': {}},
#  {'verb': 'согласиться', 'countdata': {}},
#  {'verb': 'теряться', 'countdata': {'в': 1, 'от': 1}},
#  {'verb': 'представляться', 'countdata': {'по': 1}},
#  {'verb': 'владеть', 'countdata': {}},
#  {'verb': 'уметь', 'countdata': {}},
#  {'verb': 'решать', 'countdata': {}},
#  {'verb': 'ставить', 'countdata': {'на': 1}},
#  {'verb': 'разойтись', 'countdata': {'по': 1}},
#  {'verb': 'делиться', 'countdata': {'от': 1, 'на': 1}},
#  {'verb': 'позволить', 'countdata': {}},
#  {'verb': 'спросить', 'countdata': {}},
#  {'verb': 'пострелять', 'countdata': {'из': 1, 'во': 1}},
#  {'verb': 'называться', 'countdata': {}},
#  {'verb': 'раскрываться', 'countdata': {'на': 1}},
#  {'verb': 'оставлять', 'countdata': {'на': 1}},
#  {'verb': 'зависеть', 'countdata': {'от': 1, 'на': 1}},
#  {'verb': 'сохраняться', 'countdata': {'между': 1}},
#  {'verb': 'лишаться', 'countdata': {'на': 1}},
#  {'verb': 'удивлять', 'countdata': {}},
#  {'verb': 'получаться', 'countdata': {'в': 1}},
#  {'verb': 'доказать', 'countdata': {'в': 1}},
#  {'verb': 'стрелять', 'countdata': {}},
#  {'verb': 'расстреливать', 'countdata': {}},
#  {'verb': 'возрасти', 'countdata': {'в': 1, 'на': 1}},
#  {'verb': 'утомляться', 'countdata': {}},
#  {'verb': 'прибегать', 'countdata': {'к': 1}},
#  {'verb': 'вызывать', 'countdata': {'у': 1}},
#  {'verb': 'рассказывать', 'countdata': {'о': 1, 'про': 1}},
#  {'verb': 'голосовать', 'countdata': {'за': 1}},
#  {'verb': 'обижаться', 'countdata': {'на': 1}},
#  {'verb': 'выражать', 'countdata': {}},
#  {'verb': 'оказываться', 'countdata': {}},
#  {'verb': 'работать', 'countdata': {'у': 1, 'в': 2, 'с': 1}},
#  {'verb': 'брать', 'countdata': {'над': 1, 'во': 1, 'в': 1, 'на': 1}},
#  {'verb': 'удивить', 'countdata': {}},
#  {'verb': 'просыпаться', 'countdata': {}},
#  {'verb': 'помнить', 'countdata': {'о': 2}},
#  {'verb': 'казнить', 'countdata': {}},
#  {'verb': 'появляться', 'countdata': {'у': 1, 'после': 1}},
#  {'verb': 'проникнуть', 'countdata': {'с': 1, 'в': 1}},
#  {'verb': 'добиться', 'countdata': {'в': 1}},
#  {'verb': 'задавать', 'countdata': {}},
#  {'verb': 'говориться', 'countdata': {'в': 1, 'о': 1}},
#  {'verb': 'выполнять', 'countdata': {}},
#  {'verb': 'принять', 'countdata': {}},
#  {'verb': 'верить', 'countdata': {'до': 1, 'в': 1}},
#  {'verb': 'растащить', 'countdata': {}},
#  {'verb': 'огорчаться', 'countdata': {}},
#  {'verb': 'валяться', 'countdata': {'в': 1}},
#  {'verb': 'сиять', 'countdata': {}},
#  {'verb': 'вырождаться', 'countdata': {}},
#  {'verb': 'набрать', 'countdata': {}},
#  {'verb': 'раздать', 'countdata': {}},
#  {'verb': 'уехать', 'countdata': {'в': 1}},
#  {'verb': 'вникать', 'countdata': {'в': 1}},
#  {'verb': 'удаляться', 'countdata': {}},
#  {'verb': 'выработать', 'countdata': {}},
#  {'verb': 'бежать', 'countdata': {'ко': 1, 'на': 2, 'по': 1}},
#  {'verb': 'отъехать', 'countdata': {'от': 1}},
#  {'verb': 'появиться', 'countdata': {'у': 2, 'из': 1, 'в': 2}},
#  {'verb': 'выпить', 'countdata': {'по': 1}},
#  {'verb': 'послать', 'countdata': {'за': 1}},
#  {'verb': 'послушаться', 'countdata': {}},
#  {'verb': 'отправиться', 'countdata': {'в': 2, 'по': 1, 'к': 1}},
#  {'verb': 'остаться', 'countdata': {'от': 1, 'для': 1, 'без': 1}},
#  {'verb': 'делить', 'countdata': {}},
#  {'verb': 'гнать', 'countdata': {'от': 1}},
#  {'verb': 'спускаться', 'countdata': {'со': 1}},
#  {'verb': 'донести', 'countdata': {'до': 1}},
#  {'verb': 'каяться', 'countdata': {}},
#  {'verb': 'пойти', 'countdata': {}},
#  {'verb': 'выразить', 'countdata': {}},
#  {'verb': 'выйти', 'countdata': {'из': 1, 'на': 2, 'через': 1}},
#  {'verb': 'обернуться', 'countdata': {'к': 1}},
#  {'verb': 'отпустить', 'countdata': {'к': 1}},
#  {'verb': 'пускать', 'countdata': {'в': 1}},
#  {'verb': 'представлять', 'countdata': {}},
#  {'verb': 'играть', 'countdata': {'на': 1}},
#  {'verb': 'расстаться', 'countdata': {}},
#  {'verb': 'наблюдать', 'countdata': {'с': 1, 'из-за': 1}},
#  {'verb': 'развернуть', 'countdata': {}},
#  {'verb': 'печатать', 'countdata': {'в': 1}},
#  {'verb': 'полагаться', 'countdata': {}},
#  {'verb': 'въехать', 'countdata': {}},
#  {'verb': 'побелить', 'countdata': {}},
#  {'verb': 'покрасить', 'countdata': {}},
#  {'verb': 'наклеить', 'countdata': {'на': 1}},
#  {'verb': 'заглядывать', 'countdata': {}},
#  {'verb': 'потемнеть', 'countdata': {'в': 1}},
#  {'verb': 'утонуть', 'countdata': {'в': 1}},
#  {'verb': 'продлиться', 'countdata': {}},
#  {'verb': 'привыкнуть', 'countdata': {}},
#  {'verb': 'голодать', 'countdata': {}},
#  {'verb': 'перейти', 'countdata': {'на': 1}},
#  {'verb': 'ждать', 'countdata': {}},
#  {'verb': 'проявляться', 'countdata': {'в': 1}},
#  {'verb': 'подпустить', 'countdata': {'к': 1, 'для': 1}},
#  {'verb': 'платить', 'countdata': {'по': 1, 'у': 1}},
#  {'verb': 'отметить', 'countdata': {'в': 1}},
#  {'verb': 'лежать', 'countdata': {'на': 1, 'в': 1}},
#  {'verb': 'превращаться', 'countdata': {'на': 1, 'в': 1}},
#  {'verb': 'попасться', 'countdata': {'на': 1}},
#  {'verb': 'продавать', 'countdata': {}},
#  {'verb': 'сгибаться', 'countdata': {'под': 1}},
#  {'verb': 'просохнуть', 'countdata': {'по': 1}},
#  {'verb': 'находиться', 'countdata': {}},
#  {'verb': 'покинуть', 'countdata': {'в': 1}},
#  {'verb': 'проиграть', 'countdata': {'в': 1}},
#  {'verb': 'выскочить', 'countdata': {}},
#  {'verb': 'побледнеть', 'countdata': {'в': 1}},
#  {'verb': 'сломать', 'countdata': {'по': 1}},
#  {'verb': 'испытывать', 'countdata': {}},
#  {'verb': 'порадовать', 'countdata': {}},
#  {'verb': 'терпеть', 'countdata': {}},
#  {'verb': 'касаться', 'countdata': {}},
#  {'verb': 'решаться', 'countdata': {'от': 1, 'при': 1}},
#  {'verb': 'дискредитировать', 'countdata': {}},
#  {'verb': 'удаться', 'countdata': {}},
#  {'verb': 'извинить', 'countdata': {}},
#  {'verb': 'разбиваться', 'countdata': {'на': 1}},
#  {'verb': 'готовиться', 'countdata': {'до': 1}},
#  {'verb': 'давать', 'countdata': {'на': 1}},
#  {'verb': 'задыхаться', 'countdata': {}},
#  {'verb': 'драться', 'countdata': {'в': 1}},
#  {'verb': 'кормить', 'countdata': {}},
#  {'verb': 'собирать', 'countdata': {'в': 1}},
#  {'verb': 'увидеть', 'countdata': {'из': 1, 'над': 1}},
#  {'verb': 'сорить', 'countdata': {}},
#  {'verb': 'покупать', 'countdata': {}},
#  {'verb': 'поставить', 'countdata': {}},
#  {'verb': 'судить', 'countdata': {'по': 1}},
#  {'verb': 'повести', 'countdata': {}},
#  {'verb': 'выясниться', 'countdata': {'на': 1}},
#  {'verb': 'предполагать', 'countdata': {'от': 1}},
#  {'verb': 'тянуть', 'countdata': {'на': 1}},
#  {'verb': 'претерпевать', 'countdata': {'на': 1}},
#  {'verb': 'прозвучать', 'countdata': {}},
#  {'verb': 'рухнуть', 'countdata': {'для': 1}},
#  {'verb': 'звать', 'countdata': {}},
#  {'verb': 'молиться', 'countdata': {'о': 1, 'за': 1}},
#  {'verb': 'разрабатывать', 'countdata': {}},
#  {'verb': 'встать', 'countdata': {'о': 1}},
#  {'verb': 'подрабатывать', 'countdata': {'в': 1}},
#  {'verb': 'радоваться', 'countdata': {'в': 2, 'вопреки': 1}},
#  {'verb': 'победить', 'countdata': {}},
#  {'verb': 'сворачивать', 'countdata': {'в': 1}},
#  {'verb': 'поправить', 'countdata': {}},
#  {'verb': 'поднимать', 'countdata': {}},
#  {'verb': 'устремлять', 'countdata': {'к': 1}},
#  {'verb': 'противоречить', 'countdata': {}},
#  {'verb': 'позволять', 'countdata': {}},
#  {'verb': 'прекращать', 'countdata': {}},
#  {'verb': 'ожидать', 'countdata': {}},
#  {'verb': 'исключать', 'countdata': {}},
#  {'verb': 'лидировать', 'countdata': {'по': 1}},
#  {'verb': 'оставить', 'countdata': {'в': 1}},
#  {'verb': 'использоваться', 'countdata': {}},
#  {'verb': 'зачеркнуть', 'countdata': {}},
#  {'verb': 'отменить', 'countdata': {'на': 1}},
#  {'verb': 'ослабить', 'countdata': {}},
#  {'verb': 'перепачкаться', 'countdata': {}},
#  {'verb': 'пожурить', 'countdata': {}},
#  {'verb': 'стараться', 'countdata': {}},
#  {'verb': 'клясть', 'countdata': {}},
#  {'verb': 'призывать', 'countdata': {'в': 1, 'к': 1}},
#  {'verb': 'приобретать', 'countdata': {}},
#  {'verb': 'содержать', 'countdata': {}},
#  {'verb': 'осознать', 'countdata': {}},
#  {'verb': 'обставить', 'countdata': {}},
#  {'verb': 'внушать', 'countdata': {}},
#  {'verb': 'иметься', 'countdata': {'в': 3, 'у': 1, 'за': 1}},
#  {'verb': 'справиться', 'countdata': {'с': 1, 'по': 1}},
#  {'verb': 'наблюдаться', 'countdata': {'у': 1}},
#  {'verb': 'болеть', 'countdata': {}},
#  {'verb': 'подойти', 'countdata': {'к': 1}},
#  {'verb': 'качать', 'countdata': {}},
#  {'verb': 'наклонять', 'countdata': {}},
#  {'verb': 'плескать', 'countdata': {}},
#  {'verb': 'выражаться', 'countdata': {}},
#  {'verb': 'разбогатеть', 'countdata': {}},
#  {'verb': 'плакать', 'countdata': {'по': 1}},
#  {'verb': 'зародиться', 'countdata': {}},
#  {'verb': 'познакомиться', 'countdata': {'в': 1}},
#  {'verb': 'отзываться', 'countdata': {'о': 2, 'с': 1}},
#  {'verb': 'переловить', 'countdata': {'в': 1}},
#  {'verb': 'выживать', 'countdata': {'благодаря': 1}},
#  {'verb': 'избежать', 'countdata': {}},
#  {'verb': 'уверять', 'countdata': {}},
#  {'verb': 'дышать', 'countdata': {'с': 1}},
#  {'verb': 'сталкиваться', 'countdata': {'с': 1}},
#  {'verb': 'вручать', 'countdata': {}},
#  {'verb': 'помниться', 'countdata': {}},
#  {'verb': 'приговаривать', 'countdata': {}},
#  {'verb': 'читать', 'countdata': {'в': 1}},
#  {'verb': 'вскочить', 'countdata': {'на': 1}},
#  {'verb': 'открыть', 'countdata': {'на': 1}},
#  {'verb': 'скользнуть', 'countdata': {}},
#  {'verb': 'запереть', 'countdata': {'за': 1}},
#  {'verb': 'делаться', 'countdata': {'ради': 1, 'по': 1}},
#  {'verb': 'высекать', 'countdata': {}},
#  {'verb': 'мешать', 'countdata': {}},
#  {'verb': 'гнуть', 'countdata': {'в': 1}},
#  {'verb': 'измениться', 'countdata': {'к': 2}},
#  {'verb': 'вскрикнуть', 'countdata': {'вместо': 1}},
#  {'verb': 'заметить', 'countdata': {'вместо': 1}},
#  {'verb': 'заплатить', 'countdata': {'за': 1}},
#  {'verb': 'констатировать', 'countdata': {}},
#  {'verb': 'улыбаться', 'countdata': {}},
#  {'verb': 'привлекать', 'countdata': {'в': 1}},
#  {'verb': 'разводить', 'countdata': {'на': 1}},
#  {'verb': 'допускать', 'countdata': {}},
#  {'verb': 'лишать', 'countdata': {}},
#  {'verb': 'сознавать', 'countdata': {}},
#  {'verb': 'вводиться', 'countdata': {'в': 1}},
#  {'verb': 'руководить', 'countdata': {'в': 1}},
#  {'verb': 'перечислять', 'countdata': {'в': 1}},
#  {'verb': 'звереть', 'countdata': {}},
#  {'verb': 'махнуть', 'countdata': {}},
#  {'verb': 'кончиться', 'countdata': {}},
#  {'verb': 'нырнуть', 'countdata': {'к': 1}},
#  {'verb': 'отговорить', 'countdata': {}},
#  {'verb': 'хвалить', 'countdata': {}},
#  {'verb': 'заслуживать', 'countdata': {}},
#  {'verb': 'отправить', 'countdata': {'в': 1}},
#  {'verb': 'везти', 'countdata': {'в': 1}},
#  {'verb': 'лечить', 'countdata': {'в': 1}},
#  {'verb': 'опуститься', 'countdata': {'на': 1, 'над': 1}},
#  {'verb': 'забываться', 'countdata': {}},
#  {'verb': 'любить', 'countdata': {'от': 1}},
#  {'verb': 'находить', 'countdata': {'в': 1}},
#  {'verb': 'сверкать', 'countdata': {'в': 1, 'над': 1}},
#  {'verb': 'внести', 'countdata': {}},
#  {'verb': 'кивнуть', 'countdata': {'на': 1}},
#  {'verb': 'заедать', 'countdata': {'на': 1}},
#  {'verb': 'перестать', 'countdata': {}},
#  {'verb': 'признавать', 'countdata': {}},
#  {'verb': 'постоять', 'countdata': {'в': 1}},
#  {'verb': 'покоиться', 'countdata': {'на': 1}},
#  {'verb': 'прокомментировать', 'countdata': {}},
#  {'verb': 'обеспечивать', 'countdata': {}},
#  {'verb': 'подтверждать', 'countdata': {'в': 1}},
#  {'verb': 'сохраниться', 'countdata': {'в': 1}},
#  {'verb': 'продать', 'countdata': {}},
#  {'verb': 'соответствовать', 'countdata': {}},
#  {'verb': 'обсуждать', 'countdata': {'между': 1}},
#  {'verb': 'потупиться', 'countdata': {}},
#  {'verb': 'гласить', 'countdata': {}},
#  {'verb': 'высадиться', 'countdata': {'на': 1}},
#  {'verb': 'терять', 'countdata': {}},
#  {'verb': 'инвестировать', 'countdata': {'в': 1}},
#  {'verb': 'вырасти', 'countdata': {'на': 1}},
#  {'verb': 'напомнить', 'countdata': {'в': 1}},
#  {'verb': 'прогнозировать', 'countdata': {}},
#  {'verb': 'отвечать', 'countdata': {'за': 1}},
#  {'verb': 'действовать', 'countdata': {'на': 1}},
#  {'verb': 'перегнуться', 'countdata': {'ко': 1}},
#  {'verb': 'прохрипеть', 'countdata': {'в': 1}},
#  {'verb': 'установить', 'countdata': {'над': 1, 'с': 1}},
#  {'verb': 'тягать', 'countdata': {}},
#  {'verb': 'повлиять', 'countdata': {'на': 1}},
#  {'verb': 'уложиться', 'countdata': {'в': 1}},
#  {'verb': 'заменить', 'countdata': {}},
#  {'verb': 'перенести', 'countdata': {'в': 1}},
#  {'verb': 'обстреливать', 'countdata': {'в': 1}},
#  {'verb': 'увеличивать', 'countdata': {}},
#  {'verb': 'оказывать', 'countdata': {'на': 1}},
#  {'verb': 'выделять', 'countdata': {}},
#  {'verb': 'сомневаться', 'countdata': {}},
#  {'verb': 'попробовать', 'countdata': {}},
#  {'verb': 'вернуть', 'countdata': {}},
#  {'verb': 'скрывать', 'countdata': {}},
#  {'verb': 'прятать', 'countdata': {}},
#  {'verb': 'рассматривать', 'countdata': {}},
#  {'verb': 'жаловаться', 'countdata': {'на': 1}},
#  {'verb': 'воспринимать', 'countdata': {}},
#  {'verb': 'проявлять', 'countdata': {}},
#  {'verb': 'свидетельствовать', 'countdata': {'о': 1}},
#  {'verb': 'вылиться', 'countdata': {'в': 1}},
#  {'verb': 'выстроить', 'countdata': {}},
#  {'verb': 'разделять', 'countdata': {'по': 1}},
#  {'verb': 'напоминать', 'countdata': {}},
#  {'verb': 'стремиться', 'countdata': {}},
#  {'verb': 'следовать', 'countdata': {}},
#  {'verb': 'входить', 'countdata': {'в': 1}},
#  {'verb': 'удивиться', 'countdata': {}},
#  {'verb': 'обучать', 'countdata': {}},
#  {'verb': 'проверить', 'countdata': {}},
#  {'verb': 'обучаться', 'countdata': {}},
#  {'verb': 'применяться', 'countdata': {'в': 1}},
#  {'verb': 'выносить', 'countdata': {'из-под': 1}},
#  {'verb': 'вытеснить', 'countdata': {'от': 1}},
#  {'verb': 'переливать', 'countdata': {'в': 1}},
#  {'verb': 'разлить', 'countdata': {}},
#  {'verb': 'выплескивать', 'countdata': {'с': 1}},
#  {'verb': 'сойти', 'countdata': {'с': 1}},
#  {'verb': 'затопить', 'countdata': {}},
#  {'verb': 'посвистывать', 'countdata': {}},
#  {'verb': 'мелькнуть', 'countdata': {'за': 1}},
#  {'verb': 'стукнуть', 'countdata': {}},
#  {'verb': 'успеть', 'countdata': {'за': 1}},
#  {'verb': 'удариться', 'countdata': {'о': 1}},
#  {'verb': 'раздаться', 'countdata': {}},
#  {'verb': 'лязгнуть', 'countdata': {'через': 1, 'между': 1}},
#  {'verb': 'покидать', 'countdata': {}},
#  {'verb': 'высыпать', 'countdata': {'на': 1}},
#  {'verb': 'встречать', 'countdata': {'в': 1}},
#  {'verb': 'осуществлять', 'countdata': {'о': 1}},
#  {'verb': 'распасться', 'countdata': {'на': 1}},
#  {'verb': 'включать', 'countdata': {}},
#  {'verb': 'благодарить', 'countdata': {}},
#  {'verb': 'гарантировать', 'countdata': {}},
#  {'verb': 'возвращаться', 'countdata': {'к': 2}},
#  {'verb': 'страдать', 'countdata': {'от': 1}},
#  {'verb': 'отвергаться', 'countdata': {}},
#  {'verb': 'вести', 'countdata': {}},
#  {'verb': 'звонить', 'countdata': {'с': 1}},
#  {'verb': 'собрать', 'countdata': {}},
#  {'verb': 'приняться', 'countdata': {}},
#  {'verb': 'варить', 'countdata': {}},
#  {'verb': 'рассказать', 'countdata': {'на': 1}},
#  {'verb': 'протягивать', 'countdata': {'в': 1}},
#  {'verb': 'допустить', 'countdata': {}},
#  {'verb': 'покончить', 'countdata': {'с': 1}},
#  {'verb': 'доставать', 'countdata': {'по': 1}},
#  {'verb': 'выяснить', 'countdata': {}},
#  {'verb': 'обратиться', 'countdata': {}},
#  {'verb': 'поубивать', 'countdata': {}},
#  {'verb': 'реализоваться', 'countdata': {'в': 1}},
#  {'verb': 'подумать', 'countdata': {}},
#  {'verb': 'переодеваться', 'countdata': {}},
#  {'verb': 'подчеркивать', 'countdata': {'при': 1}},
#  {'verb': 'хлопать', 'countdata': {}},
#  {'verb': 'меняться', 'countdata': {}},
#  {'verb': 'цвести', 'countdata': {'с': 1, 'по': 1}},
#  {'verb': 'видать', 'countdata': {}},
#  {'verb': 'оправдываться', 'countdata': {}},
#  {'verb': 'сбросить', 'countdata': {}},
#  {'verb': 'отдохнуть', 'countdata': {'с': 1}},
#  {'verb': 'обстоять', 'countdata': {'с': 1}},
#  {'verb': 'выключить', 'countdata': {'в': 1}},
#  {'verb': 'выходить', 'countdata': {'для': 1}},
#  {'verb': 'обратить', 'countdata': {'на': 1}},
#  {'verb': 'проснуться', 'countdata': {'у': 1}},
#  {'verb': 'высказать', 'countdata': {}},
#  {'verb': 'заплакать', 'countdata': {}},
#  {'verb': 'расслышать', 'countdata': {}},
#  {'verb': 'вериться', 'countdata': {'в': 1}},
#  {'verb': 'пропеть', 'countdata': {}},
#  {'verb': 'катиться', 'countdata': {}},
#  {'verb': 'обследовать', 'countdata': {'прежде': 1}},
#  {'verb': 'бросить', 'countdata': {'в': 1, 'по': 1}},
#  {'verb': 'забыть', 'countdata': {}},
#  {'verb': 'придаваться', 'countdata': {}},
#  {'verb': 'изловить', 'countdata': {}},
#  {'verb': 'вестись', 'countdata': {}},
#  {'verb': 'доловить', 'countdata': {}},
#  {'verb': 'поприсутствовать', 'countdata': {'в': 1}},
#  {'verb': 'ехать', 'countdata': {'в': 1, 'с': 1}},
#  {'verb': 'образоваться', 'countdata': {'у': 1}},
#  {'verb': 'зарекомендовать', 'countdata': {'на': 1}},
#  {'verb': 'прижимать', 'countdata': {'к': 1}},
#  {'verb': 'поехать', 'countdata': {'на': 1, 'с': 1}},
#  {'verb': 'махать', 'countdata': {}},
#  {'verb': 'снять', 'countdata': {}},
#  {'verb': 'выставить', 'countdata': {'на': 1}},
#  {'verb': 'разжевать', 'countdata': {}},
#  {'verb': 'проглотить', 'countdata': {}},
#  {'verb': 'возвести', 'countdata': {'на': 1}},
#  {'verb': 'сообщать', 'countdata': {}},
#  {'verb': 'разговаривать', 'countdata': {'с': 1, 'со': 1}},
#  {'verb': 'припоминать', 'countdata': {}},
#  {'verb': 'намечаться', 'countdata': {'выше': 1, 'ниже': 1}},
#  {'verb': 'определяться', 'countdata': {}},
#  {'verb': 'сформироваться', 'countdata': {'в': 1}},
#  {'verb': 'звякнуть', 'countdata': {}},
#  {'verb': 'отцвести', 'countdata': {}},
#  {'verb': 'попадаться', 'countdata': {}},
#  {'verb': 'возражать', 'countdata': {'против': 1}},
#  {'verb': 'забалдеть', 'countdata': {}},
#  {'verb': 'полениться', 'countdata': {'под': 1}},
#  {'verb': 'заглянуть', 'countdata': {'под': 1}},
#  {'verb': 'рассмотреть', 'countdata': {'под': 1}},
#  {'verb': 'кодироваться', 'countdata': {}},
#  {'verb': 'вычислять', 'countdata': {}},
#  {'verb': 'клясться', 'countdata': {}},
#  {'verb': 'терпеться', 'countdata': {}},
#  {'verb': 'засвидетельствовать', 'countdata': {}},
#  {'verb': 'предложить', 'countdata': {'с': 1}},
#  {'verb': 'ощущать', 'countdata': {}},
#  {'verb': 'предлагаться', 'countdata': {}},
#  {'verb': 'ветшать', 'countdata': {'между': 1}},
#  {'verb': 'рассказываться', 'countdata': {'в': 1, 'о': 1}},
#  {'verb': 'искать', 'countdata': {'в': 1, 'у': 1}},
#  {'verb': 'показывать', 'countdata': {}},
#  {'verb': 'сократить', 'countdata': {}},
#  {'verb': 'обрадоваться', 'countdata': {}},
#  {'verb': 'зарабатывать', 'countdata': {'для': 1}},
#  {'verb': 'заслонять', 'countdata': {}},
#  {'verb': 'вытереть', 'countdata': {}},
#  {'verb': 'ориентироваться', 'countdata': {'на': 1, 'в': 1}},
#  {'verb': 'выбирать', 'countdata': {}},
#  {'verb': 'осуждать', 'countdata': {}},
#  {'verb': 'заинтересовать', 'countdata': {}},
#  {'verb': 'выгнать', 'countdata': {'из': 1}},
#  {'verb': 'справляться', 'countdata': {'с': 1}},
#  {'verb': 'возвеличить', 'countdata': {}},
#  {'verb': 'родиться', 'countdata': {'в': 1}},
#  {'verb': 'пояснить', 'countdata': {}},
#  {'verb': 'требовать', 'countdata': {}},
#  {'verb': 'оказать', 'countdata': {}},
#  {'verb': 'присниться', 'countdata': {}},
#  {'verb': 'затащить', 'countdata': {'в': 1}},
#  {'verb': 'пережить', 'countdata': {}},
#  {'verb': 'вызвать', 'countdata': {'к': 1}},
#  {'verb': 'сделаться', 'countdata': {'через': 1}},
#  {'verb': 'помочь', 'countdata': {}},
#  {'verb': 'браться', 'countdata': {'на': 1}},
#  {'verb': 'придумываться', 'countdata': {}},
#  {'verb': 'отказываться', 'countdata': {'от': 1}},
#  {'verb': 'собираться', 'countdata': {}},
#  {'verb': 'разозлить', 'countdata': {}},
#  {'verb': 'обостряться', 'countdata': {}},
#  {'verb': 'функционировать', 'countdata': {'в': 1}},
#  {'verb': 'задевать', 'countdata': {'при': 1, 'за': 1}},
#  {'verb': 'курить', 'countdata': {'в': 1}},
#  {'verb': 'хлебать', 'countdata': {}},
#  {'verb': 'записывать', 'countdata': {'у': 1, 'на': 1}},
#  {'verb': 'узнавать', 'countdata': {}},
#  {'verb': 'присоединяться', 'countdata': {'к': 1}},
#  {'verb': 'докладывать', 'countdata': {'в': 1}},
#  {'verb': 'отгружаться', 'countdata': {'из': 1}},
#  {'verb': 'подарить', 'countdata': {}},
#  {'verb': 'рассмешить', 'countdata': {}},
#  {'verb': 'уточнить', 'countdata': {}},
#  {'verb': 'попросить', 'countdata': {}},
#  {'verb': 'привезти', 'countdata': {'с': 1, 'в': 1}},
#  {'verb': 'перевезти', 'countdata': {'в': 1}},
#  {'verb': 'мучить', 'countdata': {'в': 1}},
#  {'verb': 'постичь', 'countdata': {'в': 1}},
#  {'verb': 'изготавливать', 'countdata': {}},
#  {'verb': 'занять', 'countdata': {}},
#  {'verb': 'занимать', 'countdata': {'в': 1}},
#  {'verb': 'соскучиться', 'countdata': {'по': 1}},
#  {'verb': 'переполнять', 'countdata': {}},
#  {'verb': 'брызгать', 'countdata': {}},
#  {'verb': 'прыгать', 'countdata': {'перед': 1}},
#  {'verb': 'задушить', 'countdata': {'в': 1}},
#  {'verb': 'разорвать', 'countdata': {'в': 1}},
#  {'verb': 'использовать', 'countdata': {'из': 1}},
#  {'verb': 'продолжать', 'countdata': {}},
#  {'verb': 'держать', 'countdata': {'до': 1}},
#  {'verb': 'перебегать', 'countdata': {}},
#  {'verb': 'набирать', 'countdata': {}},
#  {'verb': 'мчаться', 'countdata': {'со': 1}},
#  {'verb': 'переманивать', 'countdata': {}},
#  {'verb': 'поверить', 'countdata': {'в': 1}},
#  {'verb': 'резервировать', 'countdata': {'за': 1}},
#  {'verb': 'отступить', 'countdata': {'за': 1, 'от': 1}},
#  {'verb': 'охраняться', 'countdata': {'в': 1}},
#  {'verb': 'умирать', 'countdata': {}},
#  {'verb': 'попереть', 'countdata': {'на': 1}},
#  {'verb': 'предупредить', 'countdata': {'в': 1, 'о': 1}},
#  {'verb': 'признаться', 'countdata': {'в': 1}},
#  {'verb': 'коситься', 'countdata': {}},
#  {'verb': 'следить', 'countdata': {}},
#  {'verb': 'всматриваться', 'countdata': {}},
#  {'verb': 'успокоить', 'countdata': {}}]
